# %% [markdown]
# # Position Classification
#
# The second part of this work tries to predict the vertical staff line position of an object.

# %% [markdown]
# ## Training
# We'll start off by preparing our dataset. Since the input for the neural network will only be a small patch of the entire input image, we have to prepare our training data similarly. The parameters are as follows:
#
# - `group_by`: You can perform classification by staff_position or by class_name. Since the class name is already provided by the object detector, we are only interested in staff_position here
# - `ignore_classes_without_semantic_staff_position`: Some classes do not have a staff-position, such as a barline, a beam or time signatures. They are just in the scores. To not confuse our classifier, we can exclude those symbols from classification with this parameter
# - `add_padding_to_force_center`: The position classification network works best, if the object, that should be classified always appears in the center of the image. When the object is located at the very border of the image, this problematic. With this option, you can enable synthetic centering, by adding some padding to the borders, so the object of interest always appears in the center. The image is padded with a reflection of the image along the corresponding axis.
# - `width` the fixed width of the image crop, that is used for classifciation
# - `height` the fixed height of the image crop, that is used for classifciation

# %%
# %run extract_sub_image_for_classification.py --group_by staff_position --ignore_classes_without_semantic_staff_position --add_padding_to_force_center --width 224 --height 448
# Out:
# Padding images to force objects to appear in the center
# Extracting sub-images for each annotated symbol: 100%|██████████| 60/60 [01:53<00:00,  1.90s/it]

# %% [markdown]
# Next, we split our entire dataset into three disjunct datasets for training, validation and testing by running the following command. It will keep 80% of each class for training, 10% for validation and 10% for final testing.

# %%
# %run dataset_splitter.py
# Out:
# Deleting split directories...
# Splitting data into training, validation and test sets...
# Copying 21 training files of L0...
# Copying 2 validation files of L0...
# Copying 2 test files of L0...
# Copying 184 training files of L1...
# Copying 22 validation files of L1...
# Copying 22 test files of L1...
# Copying 849 training files of L2...
# Copying 106 validation files of L2...
# Copying 106 test files of L2...
# Copying 1651 training files of L3...
# Copying 206 validation files of L3...
# Copying 206 test files of L3...
# Copying 2296 training files of L4...
# Copying 286 validation files of L4...
# Copying 286 test files of L4...
# Copying 1039 training files of L5...
# Copying 129 validation files of L5...
# Copying 129 test files of L5...
# Copying 99 training files of L6...
# Copying 12 validation files of L6...
# Copying 12 test files of L6...
# Copying 98 training files of S0...
# Copying 12 validation files of S0...
# Copying 12 test files of S0...
# Copying 208 training files of S1...
# Copying 26 validation files of S1...
# Copying 26 test files of S1...
# Copying 657 training files of S2...
# Copying 81 validation files of S2...
# Copying 81 test files of S2...
# Copying 1464 training files of S3...
# Copying 182 validation files of S3...
# Copying 182 test files of S3...
# Copying 1545 training files of S4...
# Copying 192 validation files of S4...
# Copying 192 test files of S4...
# Copying 497 training files of S5...
# Copying 62 validation files of S5...
# Copying 62 test files of S5...
# Copying 2 training files of S6...
# Copying 0 validation files of S6...
# Copying 0 test files of S6...

# %% [markdown]
# The last step is now to actually run the training on the provided dataset:
# - `model_name` the name of the model to train.
# - `width` and `height` the fixed dimensions of the images, we've create above

# %%
# %run train_model.py --model_name inception_resnet_v2 --width 224 --height 448
# Out:
# C:\Programmieren\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Loading configuration and data-readers...
# Found 10610 images belonging to 14 classes.
# Found 1318 images belonging to 14 classes.
# Found 1318 images belonging to 14 classes.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 448, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 223, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 223, 111, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 223, 111, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 221, 109, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 221, 109, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 221, 109, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 221, 109, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 221, 109, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 221, 109, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 110, 54, 64)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 110, 54, 80)  5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 110, 54, 80)  240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 110, 54, 80)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 108, 52, 192) 138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 108, 52, 192) 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 108, 52, 192) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 53, 25, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 53, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 53, 25, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 53, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 53, 25, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 53, 25, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 53, 25, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 53, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 53, 25, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 53, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 53, 25, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 53, 25, 96)   18432       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 53, 25, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 53, 25, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 53, 25, 64)   12288       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 53, 25, 96)   288         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 53, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 53, 25, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 53, 25, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 53, 25, 96)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 53, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 53, 25, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 53, 25, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 53, 25, 320)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 53, 25, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 53, 25, 32)   96          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 53, 25, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 53, 25, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 53, 25, 48)   13824       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 53, 25, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 53, 25, 48)   144         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 53, 25, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 53, 25, 48)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 53, 25, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 53, 25, 32)   9216        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 53, 25, 64)   27648       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 53, 25, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 53, 25, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 53, 25, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 53, 25, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 53, 25, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 53, 25, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 53, 25, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 53, 25, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 53, 25, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 53, 25, 32)   96          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 53, 25, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 53, 25, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 53, 25, 48)   13824       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 53, 25, 32)   96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 53, 25, 48)   144         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 53, 25, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 53, 25, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 53, 25, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 53, 25, 32)   9216        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 53, 25, 64)   27648       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 53, 25, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 53, 25, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 53, 25, 64)   192         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 53, 25, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 53, 25, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 53, 25, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 53, 25, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 53, 25, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 53, 25, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 53, 25, 32)   96          conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 53, 25, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 53, 25, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 53, 25, 48)   13824       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 53, 25, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 53, 25, 48)   144         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 53, 25, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 53, 25, 48)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 53, 25, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 53, 25, 32)   9216        activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 53, 25, 64)   27648       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 53, 25, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 53, 25, 32)   96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 53, 25, 64)   192         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 53, 25, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 53, 25, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 53, 25, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_25[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 53, 25, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 53, 25, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 53, 25, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 53, 25, 32)   96          conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 53, 25, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 53, 25, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 53, 25, 48)   13824       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 53, 25, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 53, 25, 48)   144         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 53, 25, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 53, 25, 48)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 53, 25, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 53, 25, 32)   9216        activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 53, 25, 64)   27648       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 53, 25, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 53, 25, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 53, 25, 64)   192         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 53, 25, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 53, 25, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 53, 25, 64)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_31[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 53, 25, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 53, 25, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 53, 25, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 53, 25, 32)   96          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 53, 25, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 53, 25, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 53, 25, 48)   13824       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 53, 25, 32)   96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 53, 25, 48)   144         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 53, 25, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 53, 25, 48)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 53, 25, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 53, 25, 32)   9216        activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 53, 25, 64)   27648       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 53, 25, 32)   96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 53, 25, 32)   96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 53, 25, 64)   192         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 53, 25, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 53, 25, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 53, 25, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_37[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 53, 25, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 53, 25, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 53, 25, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 53, 25, 32)   96          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 53, 25, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 53, 25, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 53, 25, 48)   13824       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 53, 25, 32)   96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 53, 25, 48)   144         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 53, 25, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 53, 25, 48)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 53, 25, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 53, 25, 32)   9216        activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 53, 25, 64)   27648       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 53, 25, 32)   96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 53, 25, 32)   96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 53, 25, 64)   192         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 53, 25, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 53, 25, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 53, 25, 64)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_43[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 53, 25, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 53, 25, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 53, 25, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 53, 25, 32)   96          conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 53, 25, 32)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 53, 25, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 53, 25, 48)   13824       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 53, 25, 32)   96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 53, 25, 48)   144         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 53, 25, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 53, 25, 48)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 53, 25, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 53, 25, 32)   9216        activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 53, 25, 64)   27648       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 53, 25, 32)   96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 53, 25, 32)   96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 53, 25, 64)   192         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 53, 25, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 53, 25, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 53, 25, 64)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_49[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_54[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 53, 25, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 53, 25, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 53, 25, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 53, 25, 32)   96          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 53, 25, 32)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 53, 25, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 53, 25, 48)   13824       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 53, 25, 32)   96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 53, 25, 48)   144         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 53, 25, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 53, 25, 48)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 53, 25, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 53, 25, 32)   9216        activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 53, 25, 64)   27648       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 53, 25, 32)   96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 53, 25, 32)   96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 53, 25, 64)   192         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 53, 25, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 53, 25, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 53, 25, 64)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 53, 25, 128)  0           activation_55[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 53, 25, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 53, 25, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 53, 25, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 53, 25, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 53, 25, 32)   96          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 53, 25, 32)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 53, 25, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 53, 25, 48)   13824       activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 53, 25, 32)   96          conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 53, 25, 48)   144         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 53, 25, 32)   0           batch_normalization_62[0][0]
# ...
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=1327), HTML(value='')))
# Epoch 00002: val_acc improved from 0.53490 to 0.65857, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=1327), HTML(value='')))
# Epoch 00003: val_acc improved from 0.65857 to 0.79894, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=1327), HTML(value='')))
# Epoch 00004: val_acc improved from 0.79894 to 0.87102, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=1327), HTML(value='')))
# Epoch 00005: val_acc did not improve from 0.87102
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=1327), HTML(value='')))
# Epoch 00006: val_acc improved from 0.87102 to 0.89985, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=1327), HTML(value='')))
# Epoch 00007: val_acc improved from 0.89985 to 0.91275, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=1327), HTML(value='')))
# Epoch 00008: val_acc did not improve from 0.91275
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=1327), HTML(value='')))
# Epoch 00009: val_acc improved from 0.91275 to 0.93020, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=1327), HTML(value='')))
# Epoch 00010: val_acc did not improve from 0.93020
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=1327), HTML(value='')))
# Epoch 00011: val_acc did not improve from 0.93020
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=1327), HTML(value='')))
# Epoch 00012: val_acc improved from 0.93020 to 0.94310, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=1327), HTML(value='')))
# Epoch 00013: val_acc improved from 0.94310 to 0.94841, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=1327), HTML(value='')))
# Epoch 00014: val_acc did not improve from 0.94841
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=1327), HTML(value='')))
# Epoch 00015: val_acc improved from 0.94841 to 0.95372, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=1327), HTML(value='')))
# Epoch 00016: val_acc improved from 0.95372 to 0.96206, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=1327), HTML(value='')))
# Epoch 00017: val_acc did not improve from 0.96206
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=1327), HTML(value='')))
# Epoch 00018: val_acc did not improve from 0.96206
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=1327), HTML(value='')))
# Epoch 00019: val_acc did not improve from 0.96206
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=1327), HTML(value='')))
# Epoch 00020: val_acc did not improve from 0.96206
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=1327), HTML(value='')))
# Epoch 00021: val_acc did not improve from 0.96206
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=1327), HTML(value='')))
# Epoch 00022: val_acc improved from 0.96206 to 0.96510, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=1327), HTML(value='')))
# Epoch 00023: val_acc improved from 0.96510 to 0.97496, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=1327), HTML(value='')))
# Epoch 00024: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=1327), HTML(value='')))
# Epoch 00025: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=1327), HTML(value='')))
# Epoch 00026: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=1327), HTML(value='')))
# Epoch 00027: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=1327), HTML(value='')))
# Epoch 00028: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 28', max=1327), HTML(value='')))
# Epoch 00029: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 29', max=1327), HTML(value='')))
# Epoch 00030: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 30', max=1327), HTML(value='')))
# Epoch 00031: val_acc did not improve from 0.97496
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.5.
# HBox(children=(IntProgress(value=0, description='Epoch 31', max=1327), HTML(value='')))
# Epoch 00032: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 32', max=1327), HTML(value='')))
# Epoch 00033: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 33', max=1327), HTML(value='')))
# Epoch 00034: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 34', max=1327), HTML(value='')))
# Epoch 00035: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 35', max=1327), HTML(value='')))
# Epoch 00036: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 36', max=1327), HTML(value='')))
# Epoch 00037: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 37', max=1327), HTML(value='')))
# Epoch 00038: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 38', max=1327), HTML(value='')))
# Epoch 00039: val_acc did not improve from 0.97496
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.25.
# HBox(children=(IntProgress(value=0, description='Epoch 39', max=1327), HTML(value='')))
# Epoch 00040: val_acc did not improve from 0.97496
# HBox(children=(IntProgress(value=0, description='Epoch 40', max=1327), HTML(value='')))
# Epoch 00041: val_acc improved from 0.97496 to 0.97648, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 41', max=1327), HTML(value='')))
# Epoch 00042: val_acc did not improve from 0.97648
# HBox(children=(IntProgress(value=0, description='Epoch 42', max=1327), HTML(value='')))
# Epoch 00043: val_acc did not improve from 0.97648
# HBox(children=(IntProgress(value=0, description='Epoch 43', max=1327), HTML(value='')))
# Epoch 00044: val_acc did not improve from 0.97648
# HBox(children=(IntProgress(value=0, description='Epoch 44', max=1327), HTML(value='')))
# Epoch 00045: val_acc improved from 0.97648 to 0.97800, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 45', max=1327), HTML(value='')))
# Epoch 00046: val_acc did not improve from 0.97800
# HBox(children=(IntProgress(value=0, description='Epoch 46', max=1327), HTML(value='')))
# Epoch 00047: val_acc did not improve from 0.97800
# HBox(children=(IntProgress(value=0, description='Epoch 47', max=1327), HTML(value='')))
# Epoch 00048: val_acc did not improve from 0.97800
# HBox(children=(IntProgress(value=0, description='Epoch 48', max=1327), HTML(value='')))
# Epoch 00049: val_acc did not improve from 0.97800
# HBox(children=(IntProgress(value=0, description='Epoch 49', max=1327), HTML(value='')))
# Epoch 00050: val_acc did not improve from 0.97800
# HBox(children=(IntProgress(value=0, description='Epoch 50', max=1327), HTML(value='')))
# Epoch 00051: val_acc did not improve from 0.97800
# HBox(children=(IntProgress(value=0, description='Epoch 51', max=1327), HTML(value='')))
# Epoch 00052: val_acc improved from 0.97800 to 0.97876, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 52', max=1327), HTML(value='')))
# Epoch 00053: val_acc did not improve from 0.97876
# HBox(children=(IntProgress(value=0, description='Epoch 53', max=1327), HTML(value='')))
# Epoch 00054: val_acc did not improve from 0.97876
# HBox(children=(IntProgress(value=0, description='Epoch 54', max=1327), HTML(value='')))
# Epoch 00055: val_acc did not improve from 0.97876
# HBox(children=(IntProgress(value=0, description='Epoch 55', max=1327), HTML(value='')))
# Epoch 00056: val_acc did not improve from 0.97876
# HBox(children=(IntProgress(value=0, description='Epoch 56', max=1327), HTML(value='')))
# Epoch 00057: val_acc improved from 0.97876 to 0.97951, saving model to 2018-05-10_inception_resnet_v2.h5
# HBox(children=(IntProgress(value=0, description='Epoch 57', max=1327), HTML(value='')))
# Epoch 00058: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 58', max=1327), HTML(value='')))
# Epoch 00059: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 59', max=1327), HTML(value='')))
# Epoch 00060: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 60', max=1327), HTML(value='')))
# Epoch 00061: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 61', max=1327), HTML(value='')))
# Epoch 00062: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 62', max=1327), HTML(value='')))
# Epoch 00063: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 63', max=1327), HTML(value='')))
# Epoch 00064: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 64', max=1327), HTML(value='')))
# Epoch 00065: val_acc did not improve from 0.97951
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.125.
# HBox(children=(IntProgress(value=0, description='Epoch 65', max=1327), HTML(value='')))
# Epoch 00066: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 66', max=1327), HTML(value='')))
# Epoch 00067: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 67', max=1327), HTML(value='')))
# Epoch 00068: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 68', max=1327), HTML(value='')))
# Epoch 00069: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 69', max=1327), HTML(value='')))
# Epoch 00070: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 70', max=1327), HTML(value='')))
# Epoch 00071: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 71', max=1327), HTML(value='')))
# Epoch 00072: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 72', max=1327), HTML(value='')))
# Epoch 00073: val_acc did not improve from 0.97951
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 0.0625.
# HBox(children=(IntProgress(value=0, description='Epoch 73', max=1327), HTML(value='')))
# Epoch 00074: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 74', max=1327), HTML(value='')))
# Epoch 00075: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 75', max=1327), HTML(value='')))
# Epoch 00076: val_acc did not improve from 0.97951
# HBox(children=(IntProgress(value=0, description='Epoch 76', max=1327), HTML(value='')))
# Epoch 00077: val_acc did not improve from 0.97951
# Epoch 00077: early stopping
#
# Loading best model from check-point and testing...
# Reporting classification statistics with micro average
#            precision    recall  f1-score   support
#
#        L0      1.000     1.000     1.000         2
#        L1      1.000     0.955     0.977        22
#        L2      0.926     0.943     0.935       106
#        L3      0.947     0.947     0.947       206
#        L4      0.986     0.965     0.975       286
#        L5      0.992     1.000     0.996       129
#        L6      1.000     1.000     1.000        12
#        S0      1.000     1.000     1.000        12
#        S1      0.963     1.000     0.981        26
#        S2      0.988     0.988     0.988        81
#        S3      0.995     1.000     0.997       182
#        S4      0.990     0.995     0.992       192
#        S5      0.984     1.000     0.992        62
#
# micro avg      0.977     0.977     0.977      1318
#
# Reporting classification statistics with macro average
#            precision    recall  f1-score   support
#
#        L0      1.000     1.000     1.000         2
#        L1      1.000     0.955     0.977        22
#        L2      0.926     0.943     0.935       106
#        L3      0.947     0.947     0.947       206
#        L4      0.986     0.965     0.975       286
#        L5      0.992     1.000     0.996       129
#        L6      1.000     1.000     1.000        12
#        S0      1.000     1.000     1.000        12
#        S1      0.963     1.000     0.981        26
#        S2      0.988     0.988     0.988        81
#        S3      0.995     1.000     0.997       182
#        S4      0.990     0.995     0.992       192
#        S5      0.984     1.000     0.992        62
#
# macro avg      0.982     0.984     0.983      1318
#
# Reporting classification statistics with weighted average
#               precision    recall  f1-score   support
#
#           L0      1.000     1.000     1.000         2
#           L1      1.000     0.955     0.977        22
#           L2      0.926     0.943     0.935       106
#           L3      0.947     0.947     0.947       206
#           L4      0.986     0.965     0.975       286
#           L5      0.992     1.000     0.996       129
#           L6      1.000     1.000     1.000        12
#           S0      1.000     1.000     1.000        12
#           S1      0.963     1.000     0.981        26
#           S2      0.988     0.988     0.988        81
#           S3      0.995     1.000     0.997       182
#           S4      0.990     0.995     0.992       192
#           S5      0.984     1.000     0.992        62
#
# weighted avg      0.977     0.977     0.977      1318
#
# Misclassified files:
# 	L1\11589.JPG-75.png is incorrectly classified as S1
# 	L2\12608.JPG-76.png is incorrectly classified as L3
# 	L2\12612.JPG-116.png is incorrectly classified as L3
# 	L2\12616.JPG-139.png is incorrectly classified as L3
# 	L2\12659.JPG-23.png is incorrectly classified as L3
# 	L2\12659.JPG-9.png is incorrectly classified as L3
# 	L2\12681.JPG-239.png is incorrectly classified as L3
# 	L3\11173.JPG-5.png is incorrectly classified as L2
# 	L3\12616.JPG-31.png is incorrectly classified as L4
# 	L3\12616.JPG-32.png is incorrectly classified as L4
# 	L3\12624.JPG-3.png is incorrectly classified as L4
# 	L3\12625.JPG-89.png is incorrectly classified as L2
# 	L3\12644.JPG-108.png is incorrectly classified as L2
# 	L3\12660.JPG-207.png is incorrectly classified as L2
# 	L3\12665.JPG-33.png is incorrectly classified as L2
# 	L3\12665.JPG-81.png is incorrectly classified as L2
# 	L3\12667.JPG-247.png is incorrectly classified as L2
# 	L3\12681.JPG-108.png is incorrectly classified as L4
# 	L4\00521.JPG-10.png is incorrectly classified as S4
# 	L4\00526.JPG-123.png is incorrectly classified as L3
# 	L4\11171.JPG-371.png is incorrectly classified as S4
# 	L4\11589.JPG-100.png is incorrectly classified as L3
# 	L4\12610.JPG-319.png is incorrectly classified as S5
# 	L4\12613.JPG-183.png is incorrectly classified as L3
# 	L4\12625.JPG-270.png is incorrectly classified as S3
# 	L4\12642.JPG-290.png is incorrectly classified as L3
# 	L4\12649.JPG-154.png is incorrectly classified as L3
# 	L4\12667.JPG-54.png is incorrectly classified as S2
# 	S2\11168.JPG-401.png is incorrectly classified as L2
# 	S4\11168.JPG-45.png is incorrectly classified as L5
# loss: 0.14777
# acc: 0.97724
# Total Accuracy: 97.72382%
# Total Error: 2.27618%
# Execution time: 37862.9s

# %% [markdown]
# For a full list of all models, you may run:

# %%
# %run models/ConfigurationFactory.py
# Out:
# Available configurations are:
# - vgg4
# - vgg_global_average
# - inception_resnet_v2
# - inception_resnet_v2_pretrained
# - vgg16
# - res_net_50
# - dense_net_201
# - res_net_4
